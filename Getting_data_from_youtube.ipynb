# %% [markdown]
# <a href="https://colab.research.google.com/github/farshid101/Helper-Code/blob/main/Getting_data_from_youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting Data from Youtube
#
#
#
# *   Helping video link : [link text](https://www.youtube.com/watch?v=SIm2W9TtzR0)
# *   Code from github : [link text](https://github.com/analyticswithadam/Python/blob/main/YouTubeComments.ipynb)

# %%
import googleapiclient.discovery
import googleapiclient.errors

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyAeVwggAZ-Z3CweUDWve2VbXxKSli3vnSs"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="jJx_QMh6sF8",
    maxResults=100
)
response = request.execute()

for item in response['items']:
    print(item['snippet']['topLevelComment']['snippet']['textDisplay'])
# Out:
# ব্যাপারটা কেমন হলো না? যার নাম যে এত কষ্ট করলো। সে তো দুনিয়া তে নাই। এটা কি এমন কোনো প্রজেক্ট যে প্রাগৈতিহাসিক যুগে আমার বসে যখন পশুপাখি ডোমিস্টিক করার জন্য wild এর সাথে লেস ওয়াইল্ড ব্রিডিং কোরাইতো তারপর ডোমেস্টিক করতো। যা গরু, ছাগল, মুরগি, টার্কি মুরগি, হাঁস, উট, দুম্বা ইত্যাদি।<br>তাই কোনো জাতি যদি ব্যাক্তি শেখ মুজিবের সাথে এমন করে?<br>I mean ছোট কালে ক্রিকেট team বানাইসিলাম আমার উপর দায়িত্ব ছিলো লোগো, স্লোগান এ গুলো বানানোর সবই করলাম কিন্তূ ভগবান বানামু কারে? I মিন idea বা idologi।<br>ধর যারে বানামু সে যদি ভাগ চায়। তাই ছবির কেউ হলে ভালো হয়। আর ভাগ চাইবো না বা তার idology দিয়া একটা মনোভাবের বিরুদ্ধে আরেকটা মনোভাব পরাজিত করে সুফল ভোগ করা। এতে যদি বিপদ হয় সে face করবো।<br>আমে দুধে মিশে adhi যায় বনে। সব আগের মতো কিন্তূ মানুষ টা রে কোয়া যাইবো না কারণ এ idologi সে পথ চলবে না। তাই কাম করাইয়া ফল ভোগ।
# Have your father got offspring there?
# HO Bodyr Pola. Is comparable with Amazon?
# ...

# %% [markdown]
# # Making a function

# %%
import csv
import googleapiclient.discovery
import googleapiclient.errors

def get_youtube_comments(video_id, developer_key):
    # Build the YouTube API service
    youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=developer_key)

    # Make a request to get the comments for the specified video
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=500
    )
    response = request.execute()

    # Extract comments from the response
    comments = []
    for item in response.get('items', []):
        comment_text = item['snippet']['topLevelComment']['snippet']['textDisplay']
        comments.append(comment_text)

    return comments

def save_comments_to_csv(video_id, developer_key):
    # Get comments for the specified video
    comments = get_youtube_comments(video_id, developer_key)

    # Create a CSV file and write comments to it
    #csv_file_name = f"{video_id}_comments.csv"
    csv_file_name = "padma_bridge_1.csv"
    with open(csv_file_name, 'w', newline='', encoding='utf-8') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(['Comment'])

        for comment in comments:
            csv_writer.writerow([comment])

    print(f"Comments have been saved to {csv_file_name}")

# Example usage:
video_id = "1BN1hroJMQ"
DEVELOPER_KEY = "AIzaSyDy1OS0k7ZeTqHAdUEBGfovbuhJzL9n6js"
save_comments_to_csv(video_id, DEVELOPER_KEY)

# %% [markdown]
# # checking information of csv

# %%
import pandas as pd

df=pd.read_csv("/content/padma_bridge_1.csv")

df.head()
df.count()
# Out:
# Comment    100
# dtype: int64

# %%
df.head()
# Out:
#                                              Comment
# 0  মাননীয় প্রধানমন্ত্রী জননেত্রী দেশরত্ন শেখ হাস...
# 1                         আমরা করে দেখিয়েছি বিশ্বকে
# 2  আরিচা নগরবাড়ি রুটে ৩৩০০০ ভোল্টেজ বিদ্যুৎ সঞ্চ...
# 3                                 এখন কান্দ টাকা নাই
# 4  দেশ থেকে সিমেন্ট কিনলে তো আর পনের হাজার টাকা ব...

# %%
import csv
import googleapiclient.discovery
import googleapiclient.errors

def get_youtube_comments(video_id, developer_key):
    # Build the YouTube API service
    youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=developer_key)

    # Make a request to get the comments for the specified video
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=500
    )
    response = request.execute()

    # Extract comments from the response
    comments = []
    for item in response.get('items', []):
        comment_text = item['snippet']['topLevelComment']['snippet']['textDisplay']
        comments.append(comment_text)

    return comments

def save_comments_to_csv(video_ids, developer_key, output_csv):
    # Create a CSV file and write comments to it
    with open(output_csv, 'w', newline='', encoding='utf-8') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(['Comment'])

        # Iterate through each video ID and get comments
        for video_id in video_ids:
            comments = get_youtube_comments(video_id, developer_key)

            # Write comments to the CSV file
            for comment in comments:
                csv_writer.writerow([comment])

    print(f"Comments have been saved to {output_csv}")

# Example usage with multiple video IDs:
video_ids = [ "1BN1hroJMQ" ]
DEVELOPER_KEY = "AIzaSyAeVwggAZ-Z3CweUDWve2VbXxKSli3vnSs"
output_csv = "main_pandma_bridge_1.csv"

save_comments_to_csv(video_ids, DEVELOPER_KEY, output_csv)

# %% [markdown]
# # Making function that will take multiple video id and put into one single csv file

# %%
import csv
import googleapiclient.discovery
import googleapiclient.errors

def get_youtube_comments(video_id, developer_key):
    # Build the YouTube API service
    youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=developer_key)

    # Make a request to get the comments for the specified video
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=1000
    )
    response = request.execute()

    # Extract comments from the response
    comments = []
    for item in response.get('items', []):
        comment_text = item['snippet']['topLevelComment']['snippet']['textDisplay']
        comments.append(comment_text)

    return comments

def save_comments_to_csv(video_ids, developer_key, output_csv):
    # Create a CSV file and write comments to it
    with open(output_csv, 'w', newline='', encoding='utf-8') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(['Comment'])

        # Iterate through each video ID and get comments
        for video_id in video_ids:
            comments = get_youtube_comments(video_id, developer_key)

            # Write comments to the CSV file
            for comment in comments:
                csv_writer.writerow([comment])

    print(f"Comments have been saved to {output_csv}")

# Example usage with multiple video IDs:
video_ids = [ "z_atOd7S3xU" ,"iAcowXEDVKA" ,"g5FZkvo1J68"  ]
DEVELOPER_KEY = "AIzaSyAeVwggAZ-Z3CweUDWve2VbXxKSli3vnSs"
output_csv = "main_pandma_bridge_4.csv"

save_comments_to_csv(video_ids, DEVELOPER_KEY, output_csv)
# Out:
# Comments have been saved to main_pandma_bridge_4.csv

# %%
import pandas as pd

df_1=pd.read_csv("/content/main_pandma_bridge_4.csv")

# %%
df_1.count()
# Out:
# Comment    285
# dtype: int64

# %%
df_1.sample(20)
# Out:
#                                                Comment
# 87   আমাদের জাতী হিসেবে গর্ব করা উচিত। আমরা শেখ হাস...
# 58   সবার কমেন্ট পড়লাম। তাতে যা বুঝলাম, সময় বেশি ভা...
# 44    ভাই এতো গাজার দাম বাড়ে ,তবু তোদের খাওয়া কমে না 😢
# 187                                         Bangladesh
# 225                        আমিনামাছকেঅনেকভালোবাসি❤❤❤❤❤
# 189           I am seeing this video from Bangladesh ❤
# 145                                        হাছিনা ভুয়া
# 200                                              India
# 91   প্রাণের প্রিয় ভাঙ্গা শহর দেখলেই মন টা জুড়িয়ে যায়।
# 105      Padma Setur ses pothe bolce setu dekha jacce😅
# 118                     সাংবাদিকদের আসলেই কোনো কাজ নেই
# 130                            জয় বাংলা জয় বঙ্গবন্ধু
# 53   ভাড়া বেশি নেওয়া হচ্ছে।<br>বাসের থেকে অতিরিক্ত ...
# 184  বিশ্বাস করেন ভাই আমি স্বপ্নে জীবনে পদ্মা সেতু ...
# 25      বাসের থেকে ট্রেনের ভাড়া বেশি, অতঃপর ট্রেনে লচ
# 258                     Bangladesh theke video dheki🇧🇩
# ...

# %% [markdown]
# # Adding multiple csv file to one csv file [ function ]

# %%
import pandas as pd

def merge_csv_files(file_paths, output_path):
    # Initialize an empty DataFrame to store the combined data
    combined_data = pd.DataFrame()

    # Loop through each file path and read the CSV data
    for path in file_paths:
        data = pd.read_csv(path)
        combined_data = combined_data.append(data, ignore_index=True)

    # Write the combined data to a new CSV file
    combined_data.to_csv(output_path, index=False)

# Example usage:
file_paths = ['/content/main_pandma_bridge.csv', '/content/main_pandma_bridge_1.csv', '/content/main_pandma_bridge_3.csv', '/content/main_pandma_bridge_4.csv']
output_path = '/content/Padma_Bridge_DataSet_comment.csv'

merge_csv_files(file_paths, output_path)
# Out:
# <ipython-input-24-807d65bed12f>:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data, ignore_index=True)
# <ipython-input-24-807d65bed12f>:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data, ignore_index=True)
# <ipython-input-24-807d65bed12f>:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data, ignore_index=True)
# <ipython-input-24-807d65bed12f>:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(data, ignore_index=True)

# %%
import pandas as pd

df_1=pd.read_csv("/content/Padma_Bridge_DataSet_comment.csv")

df_1.count()
# Out:
# Comment    2050
# dtype: int64
